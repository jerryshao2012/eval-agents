# %% [markdown]
# # 02: Running the Agent
#
# In Notebook 01 we explored the dataset and tools. This notebook shows how to run the
# `KnowledgeGroundedAgent` in practice.
#
# ## What You'll Learn
#
# 1. The agent's PlanReAct architecture and the `AgentResponse` data structure
# 2. Running a question with live progress display
# 3. Inspecting the response: plan, tool calls, sources, and reasoning
# 4. Multi-turn conversations using session state
# 5. Observability with Langfuse tracing
#
# ## Prerequisites
#
# Complete Notebook 01. You'll need `GOOGLE_API_KEY` in your `.env` file.
# For tracing (Section 4): `LANGFUSE_PUBLIC_KEY` and `LANGFUSE_SECRET_KEY` are also required.

# %%
import os
import uuid
from pathlib import Path

from aieng.agent_evals.knowledge_qa import KnowledgeGroundedAgent
from aieng.agent_evals.knowledge_qa.notebook import display_response, run_with_display
from aieng.agent_evals.langfuse import init_tracing
from dotenv import load_dotenv
from rich.console import Console
from rich.panel import Panel
from rich.table import Table


if Path("").absolute().name == "eval-agents":
    print(f"Working directory: {Path('').absolute()}")
else:
    os.chdir(Path("").absolute().parent.parent)
    print(f"Working directory set to: {Path('').absolute()}")

load_dotenv(verbose=True)
console = Console(width=100)
# Out:
# Working directory set to: /Users/jerryshao/Documents/projects/IBM/ai/eval-agents

# %% [markdown]
# ## 1. Agent Architecture
#
# The `KnowledgeGroundedAgent` is built on Google ADK and combines two patterns:
#
# **PlanReAct** — Before executing, the agent produces an explicit research plan with numbered
# steps. Each step has a type (`SEARCH`, `FETCH`, `ANALYZE`) and a status that transitions from
# `pending` → `in_progress` → `completed` (or `failed`/`skipped`). The plan can be revised
# mid-run if the agent encounters unexpected results.
#
# **ReAct loop** — Within each step, the agent alternates between reasoning (Thought), acting
# (tool call), and observing (tool response).
#
# ### The `AgentResponse` Object
#
# After running, `agent.answer_async(question)` returns an `AgentResponse`:
#
# | Field | Type | Description |
# |-------|------|-------------|
# | `text` | `str` | The final answer |
# | `plan` | `ResearchPlan` | Numbered steps with statuses |
# | `tool_calls` | `list[dict]` | Every tool invocation during execution |
# | `sources` | `list[GroundingChunk]` | URLs used as evidence |
# | `reasoning_chain` | `list[str]` | The model's intermediate reasoning |
# | `total_duration_ms` | `int` | Wall-clock execution time |

# %%
agent = KnowledgeGroundedAgent(enable_planning=True)

config_table = Table(title="Agent Configuration", show_header=False)
config_table.add_column("Setting", style="cyan")
config_table.add_column("Value", style="white")
config_table.add_row("Model", agent.model)
config_table.add_row("Planning", "PlanReAct (enabled)")
config_table.add_row("Session Service", "InMemorySessionService")
config_table.add_row("Tools", "google_search, web_fetch, fetch_file, grep_file, read_file")

console.print(config_table)
# Out:
# /Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/features/_feature_decorator.py:72: UserWarning: [EXPERIMENTAL] feature FeatureName.AGENT_CONFIG is enabled.
#   check_feature_enabled()
#                               Agent Configuration
# ┌─────────────────┬────────────────────────────────────────────────────────────┐
# │ Model           │ gemini-2.5-flash                                           │
# │ Planning        │ PlanReAct (enabled)                                        │
# │ Session Service │ InMemorySessionService                                     │
# │ Tools           │ google_search, web_fetch, fetch_file, grep_file, read_file │
# └─────────────────┴────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 2. Running a Question
#
# `run_with_display` executes the agent in a Jupyter notebook with a live progress display showing:
#
# - The research plan with step statuses (updating in real time)
# - Tool calls as they fire
#
# We'll use a question that requires web search — the agent must find and verify a specific fact,
# not recall it from training data.

# %%
question = "When was the highest single-day snowfall recorded in Toronto, and how much snow fell?"

response = await run_with_display(agent, question)
# Out:
# <div style="max-width: 800px;">
# <div style="padding: 10px; background: #cfe2ff; border-radius: 8px; margin-bottom: 8px;"><b>Question:</b> When was the highest single-day snowfall recorded in Toronto, and how much snow fell?</div>
# <div style="font-family: monospace; padding: 10px; background: #e9ecef; border-radius: 8px; margin-top: 8px;">
# <div style="font-weight: bold; margin-bottom: 8px;">🔧 Tool Calls (3)</div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'highest single-day snowfall Toronto'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🌐 <b>web_fetch</b> <span style="color: #6c757d;">{'url': 'https://www.cp24.com/local/toronto/2026/01/26/wh...</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🌐 <b>web_fetch</b> <span style="color: #6c757d;">{'url': 'https://watchers.news/2026/01/26/toronto-pearson...</span></div>
# </div>
# </div><div style="margin-top: 12px; padding: 10px; background: #d4edda; border-radius: 8px;">✓ Complete in 19.2s | 3 tool calls | 9 sources</div>

# %%
display_response(
    console,
    response.text,
    subtitle=(
        f"Duration: {response.total_duration_ms / 1000:.1f}s  |  "
        f"Tool calls: {len(response.tool_calls)}  |  "
        f"Sources: {len(response.sources)}"
    ),
)
# Out:
# ╭───────────────────────────────────────────── Answer ─────────────────────────────────────────────╮
# │ The highest single-day snowfall in Toronto was recorded on January 25, 2026.                     │
# │                                                                                                  │
# │  • In downtown Toronto, an estimated 56 centimeters of snow fell.                                │
# │  • At Toronto Pearson International Airport, the official record was 46 centimeters (18.1        │
# │    inches).                                                                                      │
# ╰──────────────────────── Duration: 19.2s  |  Tool calls: 3  |  Sources: 9 ────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The CP24 article states, "The highest single-day snowfall in Toronto was recorded on Sunday,     │
# │ January 25, 2026. *Estimated downtown snowfall: 56 centimetres. *Pearson Airport official        │
# │ record: 46 centimetres (eclipsing the previous record of 36.8 centimetres from January 23,       │
# │ 1966)." The Watchers.news article confirms, "The highest single-day snowfall recorded at Toronto │
# │ Pearson International Airport was 46 cm (18.1 inches) on January 25, 2026."                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### 2.1 Inspecting the Response
#
# The `AgentResponse` object contains the full execution trace.

# %%
plan = response.plan

plan_table = Table(title="Research Plan")
plan_table.add_column("#", style="cyan", width=3)
plan_table.add_column("Step", style="white")
plan_table.add_column("Type", style="dim", width=12)
plan_table.add_column("Status", style="green")

for step in plan.steps:
    icon = {"completed": "✓", "failed": "✗", "skipped": "○"}.get(step.status.value, "·")
    desc = step.description[:70] + "..." if len(step.description) > 70 else step.description
    plan_table.add_row(str(step.step_id), desc, step.step_type, f"{icon} {step.status.value}")

console.print(plan_table)
# Out:
#                                            Research Plan
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ #   ┃ Step                                                          ┃ Type         ┃ Status      ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 1   │ Search Google for "highest single-day snowfall Toronto" to    │ research     │ ✓ completed │
# │     │ find potent...                                                │              │             │
# │ 2   │ From the search results, identify reliable sources (e.g.,     │ research     │ ○ skipped   │
# │     │ meteorologic...                                               │              │             │
# │ 3   │ Use `web_fetch` on the most promising URL to extract the      │ research     │ ○ skipped   │
# │     │ exact date an...                                              │              │             │
# │ 4   │ Verify the information from the fetched content.              │ research     │ ○ skipped   │
# └─────┴───────────────────────────────────────────────────────────────┴──────────────┴─────────────┘

# %%
if response.tool_calls:
    tools_table = Table(title="Tool Calls")
    tools_table.add_column("#", style="dim", width=3)
    tools_table.add_column("Tool", style="cyan", width=16)
    tools_table.add_column("Arguments (truncated)", style="white")

    for i, tc in enumerate(response.tool_calls[:15], 1):
        name = tc.get("name", "unknown")
        args = str(tc.get("args", {}))
        args = args[:70] + "..." if len(args) > 70 else args
        tools_table.add_row(str(i), name, args)

    if len(response.tool_calls) > 15:
        tools_table.add_row("...", f"({len(response.tool_calls) - 15} more)", "")

    console.print(tools_table)
else:
    console.print("[dim]No tool calls recorded[/dim]")
# Out:
#                                              Tool Calls
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Tool             ┃ Arguments (truncated)                                                   ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1   │ google_search    │ {'query': 'highest single-day snowfall Toronto'}                        │
# │ 2   │ web_fetch        │ {'url':                                                                 │
# │     │                  │ 'https://www.cp24.com/local/toronto/2026/01/26/what-a-winter-w...       │
# │ 3   │ web_fetch        │ {'url':                                                                 │
# │     │                  │ 'https://watchers.news/2026/01/26/toronto-pearson-sets-all-tim...       │
# └─────┴──────────────────┴─────────────────────────────────────────────────────────────────────────┘

# %%
if response.sources:
    seen: set[str] = set()
    sources_table = Table(title="Sources")
    sources_table.add_column("#", style="dim", width=3)
    sources_table.add_column("URL", style="blue")

    for src in response.sources:
        if src.uri and src.uri not in seen:
            seen.add(src.uri)
            url = src.uri[:85] + "..." if len(src.uri) > 85 else src.uri
            sources_table.add_row(str(len(seen)), url)
        if len(seen) >= 10:
            break

    console.print(sources_table)
else:
    console.print("[dim]No sources recorded[/dim]")
# Out:
#                                              Sources
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ #   ┃ URL                                                                                      ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1   │ https://watchers.news/2026/01/26/toronto-pearson-sets-all-time-daily-snowfall-record-... │
# │ 2   │ https://www.cp24.com/local/toronto/2026/01/26/what-a-winter-wallop-storm-sets-new-sin... │
# │ 3   │ https://www.theweathernetwork.com/en/news/weather/severe/photos-major-winter-storm-hi... │
# │ 4   │ https://www.youtube.com/shorts/jSKOZFCfFiQ                                               │
# │ 5   │ https://snowbrains.com/toronto-just-faced-its-snowiest-day-on-record/                    │
# │ 6   │ https://ground.news/article/sunday-was-the-single-snowiest-day-in-toronto-history-her... │
# │ 7   │ https://torontolife.com/city/yesterdays-snowfall-was-the-biggest-single-day-snowstorm... │
# │ 8   │ https://www.ctvnews.ca/toronto/article/toronto-digs-out-from-the-biggest-single-day-s... │
# │ 9   │ https://www.currentresults.com/Yearly-Weather/Canada/ON/Toronto/extreme-annual-toront... │
# └─────┴──────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 3. Multi-Turn Conversations
#
# The agent uses an `InMemorySessionService` to maintain conversation context across turns.
# Pass the same `session_id` to link questions together — the agent will use prior context
# when answering follow-up questions.

# %%
session_id = str(uuid.uuid4())
console.print(f"Session ID: [dim]{session_id}[/dim]\n")

# First turn: establish a subject
response1 = await agent.answer_async(
    "What is the capital of France?",
    session_id=session_id,
)
display_response(console, response1.text, title="Turn 1")

# Second turn: follow-up that references the prior context
response2 = await agent.answer_async(
    "What is the official language spoken there?",
    session_id=session_id,
)
display_response(console, response2.text, title="Turn 2 (follow-up)")
# Out:
# Session ID: 711ad12a-c610-4fc9-b8a3-5b7ef136c624
# 2026-06-12 16:48:48,229 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What is the capital of France?...
# 2026-06-12 16:48:48,358 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-06-12 16:48:49,879 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-06-12 16:48:49,881 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'capital of France'})
# 2026-06-12 16:48:49,895 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-06-12 16:48:50,063 WARNING aieng.agent_evals.tools.search: Search failed (attempt 1/3): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 9.940226459s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}. Retrying in 1s...
# 2026-06-12 16:48:51,068 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-06-12 16:48:51,200 WARNING aieng.agent_evals.tools.search: Search failed (attempt 2/3): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 8.800433409s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '8s'}]}}. Retrying in 2s...
# 2026-06-12 16:48:53,202 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-06-12 16:48:53,339 ERROR aieng.agent_evals.tools.search: Search failed after 3 attempts: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.664932215s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# 2026-06-12 16:48:53,342 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: google_search failed - 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.664932215s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# 2026-06-12 16:48:53,370 INFO google_adk.google.adk.models.gemini_context_cache_manager: Request below Gemini minimum cache size (2896 < 4096 tokens)
# 2026-06-12 16:48:53,371 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-06-12 16:48:53,661 ERROR google_adk.google.adk.workflow._node_runner: Node execution failed with exception
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 272, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 8410, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 6953, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1651, in async_request
#     result = await self._async_request(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1584, in _async_request
#     return await self._async_retry(  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 112, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 157, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/_utils.py", line 111, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 116, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1515, in _async_request_once
#     await errors.APIError.raise_for_async_response(response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 247, in raise_for_async_response
#     await cls.raise_error_async(status_code, response_json, response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 269, in raise_error_async
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.348572556s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 129, in run
#     await self._execute_node(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 248, in _execute_node
#     await self._run_node_loop(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 262, in _run_node_loop
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_base_node.py", line 216, in run
#     async for item in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 547, in _run_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_llm_agent_wrapper.py", line 380, in run_llm_agent_as_node
#     async for event in run_iter:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py", line 279, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 503, in _run_async_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 825, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 904, in _run_one_step_async
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1295, in _call_llm_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1273, in _call_llm_with_tracing
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1356, in _run_and_handle_error
#     async for response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 410, in _run_and_handle_error
#     raise model_error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 383, in _run_and_handle_error
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 292, in generate_content_async
#     raise _ResourceExhaustedError(ce) from ce
# google.adk.models.google_llm._ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.348572556s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# 2026-06-12 16:48:53,663 ERROR google_adk.google.adk.runners: Root node knowledge_qa failed.
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 272, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 8410, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 6953, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1651, in async_request
#     result = await self._async_request(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1584, in _async_request
#     return await self._async_retry(  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 112, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 157, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/_utils.py", line 111, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 116, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1515, in _async_request_once
#     await errors.APIError.raise_for_async_response(response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 247, in raise_for_async_response
#     await cls.raise_error_async(status_code, response_json, response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 269, in raise_error_async
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.348572556s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py", line 800, in _cleanup_root_task
#     await task
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py", line 568, in _drive_root_node
#     raise ctx.error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 129, in run
#     await self._execute_node(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 248, in _execute_node
#     await self._run_node_loop(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 262, in _run_node_loop
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_base_node.py", line 216, in run
#     async for item in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 547, in _run_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_llm_agent_wrapper.py", line 380, in run_llm_agent_as_node
#     async for event in run_iter:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py", line 279, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 503, in _run_async_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 825, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 904, in _run_one_step_async
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1295, in _call_llm_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1273, in _call_llm_with_tracing
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1356, in _run_and_handle_error
#     async for response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 410, in _run_and_handle_error
#     raise model_error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 383, in _run_and_handle_error
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 292, in generate_content_async
#     raise _ResourceExhaustedError(ce) from ce
# google.adk.models.google_llm._ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.348572556s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# 2026-06-12 16:48:53,666 WARNING aieng.agent_evals.knowledge_qa.agent: Retrying aieng.agent_evals.knowledge_qa.agent.KnowledgeGroundedAgent._run_agent_once.<locals>._run_with_retry in 4.44 seconds as it raised _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 6.348572556s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}.
# 2026-06-12 16:48:58,123 INFO google_adk.google.adk.models.gemini_context_cache_manager: Request below Gemini minimum cache size (2896 < 4096 tokens)
# 2026-06-12 16:48:58,124 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-06-12 16:48:58,411 ERROR google_adk.google.adk.workflow._node_runner: Node execution failed with exception
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 272, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 8410, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 6953, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1651, in async_request
#     result = await self._async_request(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1584, in _async_request
#     return await self._async_retry(  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 112, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 157, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/_utils.py", line 111, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 116, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1515, in _async_request_once
#     await errors.APIError.raise_for_async_response(response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 247, in raise_for_async_response
#     await cls.raise_error_async(status_code, response_json, response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 269, in raise_error_async
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.594438884s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 129, in run
#     await self._execute_node(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 248, in _execute_node
#     await self._run_node_loop(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 262, in _run_node_loop
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_base_node.py", line 216, in run
#     async for item in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 547, in _run_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_llm_agent_wrapper.py", line 380, in run_llm_agent_as_node
#     async for event in run_iter:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py", line 279, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 503, in _run_async_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 825, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 904, in _run_one_step_async
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1295, in _call_llm_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1273, in _call_llm_with_tracing
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1356, in _run_and_handle_error
#     async for response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 410, in _run_and_handle_error
#     raise model_error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 383, in _run_and_handle_error
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 292, in generate_content_async
#     raise _ResourceExhaustedError(ce) from ce
# google.adk.models.google_llm._ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.594438884s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
# 2026-06-12 16:48:58,413 ERROR google_adk.google.adk.runners: Root node knowledge_qa failed.
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 272, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 8410, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py", line 6953, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1651, in async_request
#     result = await self._async_request(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1584, in _async_request
#     return await self._async_retry(  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 112, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 157, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/_utils.py", line 111, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py", line 116, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py", line 1515, in _async_request_once
#     await errors.APIError.raise_for_async_response(response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 247, in raise_for_async_response
#     await cls.raise_error_async(status_code, response_json, response)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py", line 269, in raise_error_async
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.594438884s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py", line 800, in _cleanup_root_task
#     await task
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py", line 568, in _drive_root_node
#     raise ctx.error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 129, in run
#     await self._execute_node(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 248, in _execute_node
#     await self._run_node_loop(ctx, node_input)
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py", line 262, in _run_node_loop
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_base_node.py", line 216, in run
#     async for item in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 547, in _run_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_llm_agent_wrapper.py", line 380, in run_llm_agent_as_node
#     async for event in run_iter:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py", line 279, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py", line 503, in _run_async_impl
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 825, in run_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 904, in _run_one_step_async
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1295, in _call_llm_async
#     async for event in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1273, in _call_llm_with_tracing
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 1356, in _run_and_handle_error
#     async for response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 410, in _run_and_handle_error
#     raise model_error
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 383, in _run_and_handle_error
#     async for llm_response in agen:
#   File "/Users/jerryshao/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py", line 292, in generate_content_async
#     raise _ResourceExhaustedError(ce) from ce
# google.adk.models.google_llm._ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.594438884s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
# 2026-06-12 16:48:58,416 WARNING aieng.agent_evals.knowledge_qa.agent: Retrying aieng.agent_evals.knowledge_qa.agent.KnowledgeGroundedAgent._run_agent_once.<locals>._run_with_retry in 5.42 seconds as it raised _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# ...
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:116, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     115 if is_async:
# --> 116     result = await fn(*args, **kwargs)
#     117 else:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1515, in BaseApiClient._async_request_once(self, http_request, stream)
#    1507 response = await self._aiohttp_session.request(  # type: ignore[union-attr]
#    1508     method=http_request.method,
#    1509     url=url,
#    (...)   1513     **self._async_client_session_request_args,
#    1514 )
# -> 1515 await errors.APIError.raise_for_async_response(response)
#    1516 unwrapped_response: Any = response
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py:247, in APIError.raise_for_async_response(cls, response)
#     245     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 247 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py:269, in APIError.raise_error_async(cls, status_code, response_json, response)
#     268 if 400 <= status_code < 500:
# --> 269   raise ClientError(status_code, response_json, response)
#     270 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 22.841972017s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:116, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     115 if is_async:
# --> 116     result = await fn(*args, **kwargs)
#     117 else:
#
# File ~/Documents/projects/IBM/ai/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:597, in KnowledgeGroundedAgent._run_agent_once.<locals>._run_with_retry()
#     585 @retry(
#     586     retry=retry_if_exception(is_retryable_api_error),
#     587     wait=wait_exponential_jitter(
#    (...)    595 )
#     596 async def _run_with_retry() -> dict[str, Any]:
# --> 597     return await self._run_agent_once_inner(question, adk_session_id)
#
# File ~/Documents/projects/IBM/ai/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:561, in KnowledgeGroundedAgent._run_agent_once_inner(self, question, adk_session_id)
#     560 event_count = 0
# --> 561 async for event in self._runner.run_async(
#     562     user_id="user",
#     563     session_id=adk_session_id,
#     564     new_message=content,
#     565 ):
#     566     event_count += 1
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:997, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config, yield_user_message)
#     987 async with aclosing(
#     988     self._run_node_async(
#     989         user_id=user_id,
#    (...)    995     )
#     996 ) as agen:
# --> 997   async for event in agen:
#     998     yield event
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:582, in Runner._run_node_async(self, user_id, session_id, new_message, run_config, yield_user_message, node)
#     581 finally:
# --> 582   await self._cleanup_root_task(task, self.agent.name)
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:800, in Runner._cleanup_root_task(self, task, node_name)
#     799 try:
# --> 800   await task
#     801 except asyncio.CancelledError:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:568, in Runner._run_node_async.<locals>._drive_root_node()
#     567   if ctx.error:
# --> 568     raise ctx.error
#     569 finally:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py:129, in NodeRunner.run(self, node_input, resume_inputs)
#     128 ctx._telemetry_context = telemetry_context
# --> 129 await self._execute_node(ctx, node_input)
#     130 await self._flush_output_and_deltas(ctx)
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py:248, in NodeRunner._execute_node(self, ctx, node_input)
#     247   else:
# --> 248     await self._run_node_loop(ctx, node_input)
#     249 except NodeInterruptedError:
#     250   # A dynamic child interrupted via ctx.run_node().
#     251   # The child's interrupt_ids are already on ctx
#     252   # (set by the schedule callback). Nothing more to do —
#     253   # the caller reads ctx.interrupt_ids.
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_node_runner.py:262, in NodeRunner._run_node_loop(self, ctx, node_input)
#     261 async with Aclosing(self._node.run(ctx=ctx, node_input=node_input)) as agen:
# --> 262   async for event in agen:
#     263     self._track_event_in_context(event, ctx)
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_base_node.py:216, in BaseNode.run(self, ctx, node_input)
#     215 async with Aclosing(self._run_impl(ctx=ctx, node_input=node_input)) as agen:
# --> 216   async for item in agen:
#     217     if item is None:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:547, in LlmAgent._run_impl(self, ctx, node_input)
#     544 async with Aclosing(
#     545     run_llm_agent_as_node(self, ctx=ctx, node_input=node_input)
#     546 ) as agen:
# --> 547   async for event in agen:
#     548     # Keep the agent's true event author so the outer NodeRunner does
#     549     # not overwrite it with the parent workflow's event_author.
#     550     if event.author:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/workflow/_llm_agent_wrapper.py:380, in run_llm_agent_as_node(agent, ctx, node_input)
#     379 async with aclosing(run_method) as run_iter:
# --> 380   async for event in run_iter:
#     381     yield event
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:279, in BaseAgent.run_async(self, parent_context)
#     278 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 279   async for event in agen:
#     280     yield event
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:503, in LlmAgent._run_async_impl(self, ctx)
#     502 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 503   async for event in agen:
#     504     self.__maybe_save_output_to_state(event)
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:825, in BaseLlmFlow.run_async(self, invocation_context)
#     824 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 825   async for event in agen:
#     826     last_event = event
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:904, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     899 async with Aclosing(
#     900     self._call_llm_async(
#     901         invocation_context, llm_request, model_response_event
#     902     )
#     903 ) as agen:
# --> 904   async for llm_response in agen:
#     905     # Postprocess after calling the LLM.
#     906     async with Aclosing(
#     907         self._postprocess_async(
#     908             invocation_context,
#    (...)    912         )
#     913     ) as agen:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1295, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#    1294 async with Aclosing(_call_llm_with_tracing()) as agen:
# -> 1295   async for event in agen:
#    1296     yield event
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1273, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#    1264 async with Aclosing(
#    1265     self._run_and_handle_error(
#    1266         responses_generator,
#    (...)   1271     )
#    1272 ) as agen:
# -> 1273   async for llm_response in agen:
#    1274     trace_call_llm(
#    1275         invocation_context,
#    1276         model_response_event.id,
#    (...)   1279         span,
#    1280     )
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1356, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event, call_llm_span)
#    1347 async with Aclosing(
#    1348     _run_and_handle_error(
#    1349         response_generator,
#    (...)   1354     )
#    1355 ) as agen:
# -> 1356   async for response in agen:
#    1357     yield response
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:410, in _run_and_handle_error(response_generator, invocation_context, llm_request, model_response_event, call_llm_span)
#     409 else:
# --> 410   raise model_error
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:383, in _run_and_handle_error(response_generator, invocation_context, llm_request, model_response_event, call_llm_span)
#     378 async with tracing.use_inference_span(
#     379     llm_request,
#     380     invocation_context,
#     381     model_response_event,
#     382 ) as gc_span:
# --> 383   async for llm_response in agen:
#     384     if gc_span:
#
# File ~/Documents/projects/IBM/ai/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:292, in Gemini.generate_content_async(self, llm_request, stream)
#     288 if ce.code == 429:
#     289   # We expect running into a Resource Exhausted error to be a common
#     290   # client error that developers would run into. We enhance the messaging
#     291   # with possible fixes to this issue.
# --> 292   raise _ResourceExhaustedError(ce) from ce
#     294 raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 22.841972017s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 12
#       8 )
#       9 display_response(console, response1.text, title="Turn 1")
#      10
#      11 # Second turn: follow-up that references the prior context
# ---> 12 response2 = await agent.answer_async(
#      13     "What is the official language spoken there?",
#      14     session_id=session_id,
#      15 )
#
# File ~/Documents/projects/IBM/ai/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:666, in KnowledgeGroundedAgent.answer_async(self, question, session_id)
#     663 current_session_id = adk_session_id
#     665 for attempt in range(MAX_EMPTY_RESPONSE_RETRIES + 1):
# --> 666     results = await self._run_agent_once(question, current_session_id)
#     668     # Check if we got a non-empty response
#     669     if results.get("final_response", "").strip():
#
# File ~/Documents/projects/IBM/ai/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:605, in KnowledgeGroundedAgent._run_agent_once(self, question, adk_session_id)
#     603     original_error = e.last_attempt.exception()
#     604     logger.error(f"API retry failed after {API_RETRY_MAX_ATTEMPTS} attempts: {original_error}")
# --> 605     raise RuntimeError(
#     606         f"API request failed after {API_RETRY_MAX_ATTEMPTS} retry attempts. Last error: {original_error}"
#     607     ) from original_error
#     608 except ClientError as e:
#     609     # Handle context overflow by resetting session
#     610     if is_context_overflow_error(e):
#
# RuntimeError: API request failed after 5 retry attempts. Last error:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/google-gemini/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 22.841972017s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}

# %% [markdown]
# ## 4. Observability with Langfuse
#
# Langfuse captures a full trace of every agent run using OpenTelemetry, giving you visibility into:
#
# - Every tool call and its arguments
# - Every LLM call with prompts and completions
# - Timing for each span
# - The full agent execution tree
#
# This is essential for debugging failures, measuring latency, and comparing configurations.
#
# ### Trace Structure
#
# ```
# Trace: agent run
# ├── Span: planning (PlanReAct)
# │   └── LLM Call: create_plan
# ├── Span: step-1-execution
# │   ├── Tool Call: google_search
# │   ├── Tool Call: web_fetch
# │   └── LLM Call: step_summary
# ├── Span: step-2-execution
# │   └── ...
# └── Span: synthesis
#     └── LLM Call: final_answer
# ```
#
# ### Prerequisites
#
# Set these in your `.env` file:
# - `LANGFUSE_PUBLIC_KEY`
# - `LANGFUSE_SECRET_KEY`
# - `LANGFUSE_HOST` (optional, defaults to `https://cloud.langfuse.com`)

# %%
langfuse_configured = all(
    [
        os.getenv("LANGFUSE_PUBLIC_KEY"),
        os.getenv("LANGFUSE_SECRET_KEY"),
    ]
)

if langfuse_configured:
    console.print("[green]✓[/green] Langfuse credentials found")
else:
    console.print("[yellow]⚠[/yellow] Langfuse credentials not found — tracing cells will be skipped")
    console.print("[dim]Set LANGFUSE_PUBLIC_KEY and LANGFUSE_SECRET_KEY in .env[/dim]")
# Out:
# ✓ Langfuse credentials found

# %%
tracing_enabled = init_tracing()

if tracing_enabled:
    console.print("[green]✓[/green] Langfuse tracing initialized")
else:
    console.print("[yellow]⚠[/yellow] Tracing not enabled (check credentials)")
# Out:
# 2026-02-25 01:13:41,689 WARNING opentelemetry.trace: Overriding of current TracerProvider is not allowed
# 2026-02-25 01:13:41,848 INFO aieng.agent_evals.langfuse: Langfuse tracing initialized successfully (endpoint: https://us.cloud.langfuse.com/api/public/otel)
# ✓ Langfuse tracing initialized

# %%
if tracing_enabled:
    from langfuse import Langfuse

    langfuse = Langfuse()
    traced_agent = KnowledgeGroundedAgent(enable_planning=True)
    traced_question = "What programming language was created by Guido van Rossum, and in what year?"

    console.print(Panel(traced_question, title="Traced Question", border_style="green"))

    with langfuse.start_as_current_span(name="knowledge-agent", input=traced_question):
        trace_id = langfuse.get_current_trace_id()
        traced_response = await traced_agent.answer_async(traced_question)
        langfuse.update_current_span(output=traced_response.text)

    display_response(
        console,
        traced_response.text,
        subtitle=f"Duration: {traced_response.total_duration_ms / 1000:.1f}s",
    )
else:
    console.print("[dim]Skipping (Langfuse not configured)[/dim]")
    trace_id = None
# Out:
# ╭──────────────────────────────────────── Traced Question ─────────────────────────────────────────╮
# │ What programming language was created by Guido van Rossum, and in what year?                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2026-02-25 01:13:41,956 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What programming language was created by Guido van Rossum, and in what year?...
# /Users/amritkrishnan/src/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:172: UserWarning: [EXPERIMENTAL] GeminiContextCacheManager: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   cache_manager = GeminiContextCacheManager(self.api_client)
# 2026-02-25 01:13:41,969 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-25 01:13:43,492 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-25 01:13:43,498 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 2 steps
# 2026-02-25 01:13:43,499 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'programming language created by Guido van Rossum and in what year'})
# 2026-02-25 01:13:43,528 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-25 01:13:47,793 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-02-25 01:13:48,428 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/u4i7evm4a20gozw6irygbp9t0m1z9gib0mg2of3e
# 2026-02-25 01:13:48,431 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-25 01:13:48,431 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-25 01:13:49,506 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-25 01:13:49,510 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://en.wikipedia.org/wiki/Python_(programming_language)', 'query': 'who created python and when was it created'})
# 2026-02-25 01:13:52,692 ERROR aieng.agent_evals.tools.web: HTTP error fetching https://en.wikipedia.org/wiki/Python_(programming_language) (after 3 retries): Client error '403 Too many requests. Please contact bot-traffic@wikimedia.org (cb6513a)' for url 'https://en.wikipedia.org/wiki/Python_(programming_language)'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
# 2026-02-25 01:13:52,695 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - HTTP 403: Too many requests. Please contact bot-traffic@wikimedia.org (cb6513a) (failed after 3 retries)
# 2026-02-25 01:13:52,721 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-25 01:13:52,722 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-25 01:13:53,634 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-25 01:13:53,638 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'who created python and when was it created', 'url': 'https://en.wikipedia.org/wiki/History_of_Python'})
# 2026-02-25 01:13:56,813 ERROR aieng.agent_evals.tools.web: HTTP error fetching https://en.wikipedia.org/wiki/History_of_Python (after 3 retries): Client error '403 Too many requests. Please contact bot-traffic@wikimedia.org (cb6513a)' for url 'https://en.wikipedia.org/wiki/History_of_Python'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
# 2026-02-25 01:13:56,814 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - HTTP 403: Too many requests. Please contact bot-traffic@wikimedia.org (cb6513a) (failed after 3 retries)
# 2026-02-25 01:13:56,824 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-25 01:13:56,825 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-25 01:13:57,929 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-25 01:13:57,931 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.wajusoft.com/blog/when-was-python-developed-all-your-questions-answered', 'query': 'who created python and when was it created'})
# 2026-02-25 01:13:58,002 INFO aieng.agent_evals.tools.web: Fetched 28810 chars from https://www.wajusoft.com/blog/when-was-python-developed-all-your-questions-answered, extracting info...
# 2026-02-25 01:13:59,630 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-02-25 01:13:59,660 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-25 01:13:59,661 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-25 01:14:00,744 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# ╭───────────────────────────────────────────── Answer ─────────────────────────────────────────────╮
# │ The programming language created by Guido van Rossum is Python. He began implementing it in      │
# │ December 1989.                                                                                   │
# ╰──────────────────────────────────────── Duration: 18.8s ─────────────────────────────────────────╯
# ╭──────────────────────────────────────────── Sources ─────────────────────────────────────────────╮
# │   https://www.wajusoft.com/blog/when-was-python-developed-all-your-questions-answered            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The article from wajusoft.com states: "Python was created by Guido van Rossum, a Dutch           │
# │ programmer. It was conceived in December 1989."                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
if tracing_enabled:
    from IPython.display import HTML, display  # noqa: A004
    from langfuse import Langfuse
    from opentelemetry import trace as otel_trace

    provider = otel_trace.get_tracer_provider()
    if hasattr(provider, "force_flush"):
        provider.force_flush(timeout_millis=5000)
    console.print("[green]✓[/green] Traces flushed to Langfuse")

    if trace_id:
        trace_url = Langfuse().get_trace_url(trace_id=trace_id)
        display(HTML(f'<p>View trace: <a href="{trace_url}" target="_blank">{trace_url}</a></p>'))
# Out:
# ✓ Traces flushed to Langfuse
# <p>View trace: <a href="https://us.cloud.langfuse.com/project/cmcup61ex00l5ad07yfo1b8k0/traces/580a47d6885cef7d9dbae8c7e139cbd6" target="_blank">https://us.cloud.langfuse.com/project/cmcup61ex00l5ad07yfo1b8k0/traces/580a47d6885cef7d9dbae8c7e139cbd6</a></p>

# %% [markdown]
# ### 4.1 Viewing Traces in the Langfuse UI
#
# Open your Langfuse project and navigate to **Traces**. Each run appears as a
# tree of spans. Useful things to look at:
#
# - **Span timeline** — which steps take the most time?
# - **Tool call arguments** — what search queries did the agent use?
# - **LLM interactions** — what did the model reason about before calling each tool?
# - **Errors** — red spans show where failures occurred
#
# You can also filter by trace name, time range, or input content.

# %% [markdown]
# ## Summary
#
# In this notebook you learned:
#
# 1. **Creating the agent** — `KnowledgeGroundedAgent(enable_planning=True)` with PlanReAct
# 2. **Running questions** — `run_with_display` for live notebook progress; `agent.answer_async` for raw access
# 3. **The `AgentResponse`** — plan, tool calls, sources, reasoning, and timing in one object
# 4. **Multi-turn conversations** — linking turns with `session_id`
# 5. **Langfuse tracing** — `init_tracing()` and the Langfuse SDK for full observability
#
# **Next:** In Notebook 03, we'll run a systematic evaluation using the DeepSearchQA benchmark.

# %%
console.print(
    Panel(
        "[green]✓[/green] Notebook complete!\n\n"
        "[cyan]Next:[/cyan] Open [bold]03_evaluation.ipynb[/bold] to evaluate the agent at scale.",
        title="Done",
        border_style="green",
    )
)
# Out:
# ╭────────────────────────────────────────────── Done ──────────────────────────────────────────────╮
# │ ✓ Notebook complete!                                                                             │
# │                                                                                                  │
# │ Next: Open 03_evaluation.ipynb to evaluate the agent at scale.                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
